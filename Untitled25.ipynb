# %% [markdown]
# <a href="https://colab.research.google.com/github/adejokeowoso/COVID-19/blob/master/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = '/titanic2.csv'
titanic = pd.read_csv(titanic)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.loc[:, ["sex", "age", "fare"]]
# Out:
#         sex   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
titanic.loc[:, ["class", "alive", "alone"]]
# Out:
#       class alive  alone
# 0     Third    no  False
# 1     First   yes  False
# 2     Third   yes   True
# 3     First   yes  False
# 4     Third    no   True
# ..      ...   ...    ...
# 886  Second    no   True
# 887   First   yes   True
# 888   Third    no  False
# 889   First   yes   True
# 890   Third    no   True
#
# [891 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
titanic.loc[:,["who", "embark_town"]]
# Out:
#        who  embark_town
# 0      man  Southampton
# 1    woman    Cherbourg
# 2    woman  Southampton
# 3    woman  Southampton
# 4      man  Southampton
# ..     ...          ...
# 886    man  Southampton
# 887  woman  Southampton
# 888  woman  Southampton
# 889    man    Cherbourg
# 890    man   Queenstown
#
# [891 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
titanic.loc[:, ["alone", "alive", "sex"]]
# Out:
#      alone alive     sex
# 0    False    no    male
# 1    False   yes  female
# 2     True   yes  female
# 3    False   yes  female
# 4     True    no    male
# ..     ...   ...     ...
# 886   True    no    male
# 887   True   yes  female
# 888  False    no  female
# 889   True   yes    male
# 890   True    no    male
#
# [891 rows x 3 columns]

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# Only return columns from start to class including all rows

# %%
titanic.loc[:,:'class']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# [891 rows x 9 columns]

# %% [markdown]
# Only return columns from start to sex column

# %%
titanic.loc[:,:'sex']
# Out:
#      survived  pclass     sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %% [markdown]
# Only return top 10 rows and 2nd ,5th and 6th columns

# %%
titanic.iloc[:10, [2,5,6]]
# Out:
#       sex  parch     fare
# 0    male      0   7.2500
# 1  female      0  71.2833
# 2  female      0   7.9250
# 3  female      0  53.1000
# 4    male      0   8.0500
# 5    male      0   8.4583
# 6    male      0  51.8625
# 7    male      1  21.0750
# 8  female      2  11.1333
# 9  female      0  30.0708

# %% [markdown]
# Only return top 5 rows and 1st ,3th and 7th columns

# %%
titanic.iloc[:5, [1,3,7]]
# Out:
#    pclass   age embarked
# 0       3  22.0        S
# 1       1  38.0        C
# 2       3  26.0        S
# 3       1  35.0        S
# 4       3  35.0        S

# %% [markdown]
# Only return records where the passenger was alone

# %%
titanic.loc[titanic['alone']==True, :]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.loc[titanic['alone']==False, :]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Only return records where the passenger was alone and did not survive the crash

# %%
titanic.loc[(titanic['alone']==True) & (titanic['alive']=='no'),:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Only return the column fare for female passengers who were In 1st class of the ship

# %%
titanic.loc[(titanic['sex']=='female') & (titanic['class']=='First'), 'fare']
# Out:
# 1       71.2833
# 3       53.1000
# 11      26.5500
# 31     146.5208
# 52      76.7292
#          ...
# 856    164.8667
# 862     25.9292
# 871     52.5542
# 879     83.1583
# 887     30.0000
# Name: fare, Length: 94, dtype: float64

# %%
titanic.loc[(titanic['sex']=='male') & (titanic['alive']== True), :]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []
